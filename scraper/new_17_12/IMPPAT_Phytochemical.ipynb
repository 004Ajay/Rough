# %% [markdown]
# ## Scraping Phytochemical and Link to their details

# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd

# %%
url = "https://cb.imsc.res.in/imppat/"
# get headers from "https://www.whatismybrowser.com/"
HEADERS = ({'User-Agent': 'Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/130.0.0.0 Safari/537.36',
            'Accept-Language': 'en-US, en;q=0.5'})

# %%
webpage = requests.get(url, headers=HEADERS)
soup = BeautifulSoup(webpage.content, "html.parser")

# %%
homeselect form-control

# %%
lst = soup.find_all("option") # , href=True
lst
# .find_all("option")
# Out:
# [<option value="">Choose from dropdown</option>,
#  <option value="/imppat/phytochemical/Abelmoschus esculentus">Abelmoschus esculentus</option>,
#  <option value="/imppat/phytochemical/Abelmoschus ficulneus">Abelmoschus ficulneus</option>,
#  <option value="/imppat/phytochemical/Abelmoschus manihot">Abelmoschus manihot</option>,
#  <option value="/imppat/phytochemical/Abelmoschus moschatus">Abelmoschus moschatus</option>,
#  <option value="/imppat/phytochemical/Abies alba">Abies alba</option>,
#  <option value="/imppat/phytochemical/Abies balsamea">Abies balsamea</option>,
#  <option value="/imppat/phytochemical/Abies grandis">Abies grandis</option>,
#  <option value="/imppat/phytochemical/Abies nephrolepis">Abies nephrolepis</option>,
#  <option value="/imppat/phytochemical/Abies pindrow">Abies pindrow</option>,
#  <option value="/imppat/phytochemical/Abies pinsapo">Abies pinsapo</option>,
#  <option value="/imppat/phytochemical/Abies spectabilis">Abies spectabilis</option>,
#  <option value="/imppat/phytochemical/Abroma augusta">Abroma augusta</option>,
#  <option value="/imppat/phytochemical/Abrus precatorius">Abrus precatorius</option>,
#  <option value="/imppat/phytochemical/Abutilon grandifolium">Abutilon grandifolium</option>,
#  <option value="/imppat/phytochemical/Abutilon hirtum">Abutilon hirtum</option>,
#  <option value="/imppat/phytochemical/Abutilon indicum">Abutilon indicum</option>,
#  <option value="/imppat/phytochemical/Abutilon pannosum">Abutilon pannosum</option>,
#  <option value="/imppat/phytochemical/Abutilon ramosum">Abutilon ramosum</option>,
#  <option value="/imppat/phytochemical/Abutilon theophrasti">Abutilon theophrasti</option>,
#  <option value="/imppat/phytochemical/Acacia aroma">Acacia aroma</option>,
#  <option value="/imppat/phytochemical/Acacia auriculiformis">Acacia auriculiformis</option>,
#  <option value="/imppat/phytochemical/Acacia caesia">Acacia caesia</option>,
#  <option value="/imppat/phytochemical/Acacia catechu">Acacia catechu</option>,
#  <option value="/imppat/phytochemical/Acacia caven">Acacia caven</option>,
#  <option value="/imppat/phytochemical/Acacia chundra">Acacia chundra</option>,
#  <option value="/imppat/phytochemical/Acacia concinna">Acacia concinna</option>,
#  <option value="/imppat/phytochemical/Acacia dealbata">Acacia dealbata</option>,
#  <option value="/imppat/phytochemical/Acacia decurrens">Acacia decurrens</option>,
#  <option value="/imppat/phytochemical/Acacia farnesiana">Acacia farnesiana</option>,
#  <option value="/imppat/phytochemical/Acacia ferruginea">Acacia ferruginea</option>,
#  <option value="/imppat/phytochemical/Acacia jacquemontii">Acacia jacquemontii</option>,
#  <option value="/imppat/phytochemical/Acacia lenticularis">Acacia lenticularis</option>,
#  <option value="/imppat/phytochemical/Acacia leucophloea">Acacia leucophloea</option>,
#  <option value="/imppat/phytochemical/Acacia mearnsii">Acacia mearnsii</option>,
#  <option value="/imppat/phytochemical/Acacia melanoxylon">Acacia melanoxylon</option>,
#  <option value="/imppat/phytochemical/Acacia modesta">Acacia modesta</option>,
#  <option value="/imppat/phytochemical/Acacia nilotica">Acacia nilotica</option>,
#  <option value="/imppat/phytochemical/Acacia pennata">Acacia pennata</option>,
#  <option value="/imppat/phytochemical/Acacia planifrons">Acacia planifrons</option>,
#  <option value="/imppat/phytochemical/Acacia polyacantha">Acacia polyacantha</option>,
#  <option value="/imppat/phytochemical/Acacia pubescens">Acacia pubescens</option>,
#  <option value="/imppat/phytochemical/Acacia schweinfurthii">Acacia schweinfurthii</option>,
#  <option value="/imppat/phytochemical/Acacia senegal">Acacia senegal</option>,
#  <option value="/imppat/phytochemical/Acacia sinuata">Acacia sinuata</option>,
#  <option value="/imppat/phytochemical/Acacia torta">Acacia torta</option>,
#  <option value="/imppat/phytochemical/Acacia tortilis">Acacia tortilis</option>,
#  <option value="/imppat/phytochemical/Acalypha australis">Acalypha australis</option>,
#  <option value="/imppat/phytochemical/Acalypha fruticosa">Acalypha fruticosa</option>,
#  <option value="/imppat/phytochemical/Acalypha hispida">Acalypha hispida</option>,
#  <option value="/imppat/phytochemical/Acalypha indica">Acalypha indica</option>,
#  <option value="/imppat/phytochemical/Acalypha wilkesiana">Acalypha wilkesiana</option>,
#  <option value="/imppat/phytochemical/Acampe praemorsa">Acampe praemorsa</option>,
#  <option value="/imppat/phytochemical/Acanthospermum hispidum">Acanthospermum hispidum</option>,
#  <option value="/imppat/phytochemical/Acanthus ilicifolius">Acanthus ilicifolius</option>,
#  <option value="/imppat/phytochemical/Acca sellowiana">Acca sellowiana</option>,
#  <option value="/imppat/phytochemical/Acer caesium">Acer caesium</option>,
#  <option value="/imppat/phytochemical/Acer negundo">Acer negundo</option>,
#  <option value="/imppat/phytochemical/Acer oblongum">Acer oblongum</option>,
#  <option value="/imppat/phytochemical/Acer pictum">Acer pictum</option>,
#  <option value="/imppat/phytochemical/Achillea millefolium">Achillea millefolium</option>,
#  <option value="/imppat/phytochemical/Achillea santolina">Achillea santolina</option>,
#  <option value="/imppat/phytochemical/Achyranthes aspera">Achyranthes aspera</option>,
#  <option value="/imppat/phytochemical/Achyranthes bidentata">Achyranthes bidentata</option>,
#  <option value="/imppat/phytochemical/Acinos alpinus">Acinos alpinus</option>,
#  <option value="/imppat/phytochemical/Acmella oleracea">Acmella oleracea</option>,
#  <option value="/imppat/phytochemical/Acmella paniculata">Acmella paniculata</option>,
#  <option value="/imppat/phytochemical/Acmella radicans">Acmella radicans</option>,
#  <option value="/imppat/phytochemical/Acokanthera oblongifolia">Acokanthera oblongifolia</option>,
#  <option value="/imppat/phytochemical/Acomastylis elata">Acomastylis elata</option>,
#  <option value="/imppat/phytochemical/Aconitum chasmanthum">Aconitum chasmanthum</option>,
#  <option value="/imppat/phytochemical/Aconitum ferox">Aconitum ferox</option>,
#  <option value="/imppat/phytochemical/Aconitum gymnandrum">Aconitum gymnandrum</option>,
#  <option value="/imppat/phytochemical/Aconitum heterophylloides">Aconitum heterophylloides</option>,
#  <option value="/imppat/phytochemical/Aconitum heterophyllum">Aconitum heterophyllum</option>,
#  <option value="/imppat/phytochemical/Aconitum lethale">Aconitum lethale</option>,
#  <option value="/imppat/phytochemical/Aconitum napellus">Aconitum napellus</option>,
#  <option value="/imppat/phytochemical/Aconitum palmatum">Aconitum palmatum</option>,
#  <option value="/imppat/phytochemical/Aconitum rotundifolium">Aconitum rotundifolium</option>,
#  <option value="/imppat/phytochemical/Aconitum soongaricum">Aconitum soongaricum</option>,
#  <option value="/imppat/phytochemical/Aconitum violaceum">Aconitum violaceum</option>,
#  <option value="/imppat/phytochemical/Acorus calamus">Acorus calamus</option>,
#  <option value="/imppat/phytochemical/Acorus gramineus">Acorus gramineus</option>,
#  <option value="/imppat/phytochemical/Acrocarpus fraxinifolius">Acrocarpus fraxinifolius</option>,
#  <option value="/imppat/phytochemical/Acronychia pedunculata">Acronychia pedunculata</option>,
#  <option value="/imppat/phytochemical/Acrostichum aureum">Acrostichum aureum</option>,
#  <option value="/imppat/phytochemical/Acrotrema arnottianum">Acrotrema arnottianum</option>,
#  <option value="/imppat/phytochemical/Actaea cimicifuga">Actaea cimicifuga</option>,
#  <option value="/imppat/phytochemical/Actaea racemosa">Actaea racemosa</option>,
#  <option value="/imppat/phytochemical/Actaea spicata">Actaea spicata</option>,
#  <option value="/imppat/phytochemical/Actinidia arguta">Actinidia arguta</option>,
#  <option value="/imppat/phytochemical/Actinidia chinensis">Actinidia chinensis</option>,
#  <option value="/imppat/phytochemical/Actinidia eriantha">Actinidia eriantha</option>,
#  <option value="/imppat/phytochemical/Actiniopteris australis">Actiniopteris australis</option>,
#  <option value="/imppat/phytochemical/Actiniopteris dichotoma">Actiniopteris dichotoma</option>,
#  <option value="/imppat/phytochemical/Actiniopteris radiata">Actiniopteris radiata</option>,
#  <option value="/imppat/phytochemical/Actinodaphne gullavara">Actinodaphne gullavara</option>,
#  <option value="/imppat/phytochemical/Actinodaphne hookeri">Actinodaphne hookeri</option>,
#  <option value="/imppat/phytochemical/Actinodaphne obovata">Actinodaphne obovata</option>,
#  <option value="/imppat/phytochemical/Actinoscirpus grossus">Actinoscirpus grossus</option>,
#  <option value="/imppat/phytochemical/Adansonia digitata">Adansonia digitata</option>,
#  <option value="/imppat/phytochemical/Adenanthera pavonina">Adenanthera pavonina</option>,
#  <option value="/imppat/phytochemical/Adenium obesum">Adenium obesum</option>,
#  <option value="/imppat/phytochemical/Adenosma indianum">Adenosma indianum</option>,
#  <option value="/imppat/phytochemical/Adenostemma lavenia">Adenostemma lavenia</option>,
#  <option value="/imppat/phytochemical/Adiantum capillus-veneris">Adiantum capillus-veneris</option>,
#  <option value="/imppat/phytochemical/Adiantum caudatum">Adiantum caudatum</option>,
#  <option value="/imppat/phytochemical/Adiantum chilense">Adiantum chilense</option>,
#  <option value="/imppat/phytochemical/Adiantum incisum">Adiantum incisum</option>,
#  <option value="/imppat/phytochemical/Anacyclus pyrethrum">Anacyclus pyrethrum</option>,
#  <option value="/imppat/phytochemical/Anagallis arvensis">Anagallis arvensis</option>,
#  <option value="/imppat/phytochemical/Anamirta cocculus">Anamirta cocculus</option>,
#  <option value="/imppat/phytochemical/Ananas comosus">Ananas comosus</option>,
#  <option value="/imppat/phytochemical/Anaphalis adnata">Anaphalis adnata</option>,
#  <option value="/imppat/phytochemical/Anaphalis busua">Anaphalis busua</option>,
#  <option value="/imppat/phytochemical/Anaphalis contorta">Anaphalis contorta</option>,
#  <option value="/imppat/phytochemical/Anaphalis margaritacea">Anaphalis margaritacea</option>,
#  <option value="/imppat/phytochemical/Anaphalis neelgerryana">Anaphalis neelgerryana</option>,
#  <option value="/imppat/phytochemical/Anaphalis triplinervis">Anaphalis triplinervis</option>,
#  <option value="/imppat/phytochemical/Anastatica hierochuntica">Anastatica hierochuntica</option>,
#  <option value="/imppat/phytochemical/Anchusa azurea">Anchusa azurea</option>,
#  <option value="/imppat/phytochemical/Anchusa strigosa">Anchusa strigosa</option>,
#  <option value="/imppat/phytochemical/Ancistrocladus heyneanus">Ancistrocladus heyneanus</option>,
#  <option value="/imppat/phytochemical/Ancistrocladus tectorius">Ancistrocladus tectorius</option>,
#  <option value="/imppat/phytochemical/Andira inermis">Andira inermis</option>,
#  <option value="/imppat/phytochemical/Andrachne telephioides">Andrachne telephioides</option>,
#  <option value="/imppat/phytochemical/Andrographis atropurpurea">Andrographis atropurpurea</option>,
#  <option value="/imppat/phytochemical/Andrographis echioides">Andrographis echioides</option>,
#  <option value="/imppat/phytochemical/Andrographis paniculata">Andrographis paniculata</option>,
#  <option value="/imppat/phytochemical/Andrographis serpyllifolia">Andrographis serpyllifolia</option>,
#  <option value="/imppat/phytochemical/Andropogon hallii">Andropogon hallii</option>,
#  <option value="/imppat/phytochemical/Androsace rotundifolia">Androsace rotundifolia</option>,
#  <option value="/imppat/phytochemical/Androsace umbellata">Androsace umbellata</option>,
#  <option value="/imppat/phytochemical/Anemarrhena asphodeloides">Anemarrhena asphodeloides</option>,
#  <option value="/imppat/phytochemical/Anemone coronaria">Anemone coronaria</option>,
#  <option value="/imppat/phytochemical/Anemone narcissiflora">Anemone narcissiflora</option>,
#  <option value="/imppat/phytochemical/Anemone obtusiloba">Anemone obtusiloba</option>,
#  <option value="/imppat/phytochemical/Anemone rivularis">Anemone rivularis</option>,
#  <option value="/imppat/phytochemical/Anethum graveolens">Anethum graveolens</option>,
#  <option value="/imppat/phytochemical/Anethum sowa">Anethum sowa</option>,
#  <option value="/imppat/phytochemical/Angelica archangelica">Angelica archangelica</option>,
#  <option value="/imppat/phytochemical/Angelica glauca">Angelica glauca</option>,
#  <option value="/imppat/phytochemical/Angelica sinensis">Angelica sinensis</option>,
#  <option value="/imppat/phytochemical/Angelica tenuissima">Angelica tenuissima</option>,
#  <option value="/imppat/phytochemical/Angelonia grandiflora">Angelonia grandiflora</option>,
#  <option value="/imppat/phytochemical/Angiopteris evecta">Angiopteris evecta</option>,
#  <option value="/imppat/phytochemical/Aniseia martinicensis">Aniseia martinicensis</option>,
#  <option value="/imppat/phytochemical/Anisochilus carnosus">Anisochilus carnosus</option>,
#  <option value="/imppat/phytochemical/Anisodus luridus">Anisodus luridus</option>,
#  <option value="/imppat/phytochemical/Anisomeles heyneana">Anisomeles heyneana</option>,
#  <option value="/imppat/phytochemical/Anisomeles indica">Anisomeles indica</option>,
#  <option value="/imppat/phytochemical/Anisomeles malabarica">Anisomeles malabarica</option>,
#  <option value="/imppat/phytochemical/Annona atemoya">Annona atemoya</option>,
#  <option value="/imppat/phytochemical/Annona cherimola">Annona cherimola</option>,
#  <option value="/imppat/phytochemical/Annona glabra">Annona glabra</option>,
#  <option value="/imppat/phytochemical/Annona montana">Annona montana</option>,
#  <option value="/imppat/phytochemical/Annona muricata">Annona muricata</option>,
#  <option value="/imppat/phytochemical/Annona purpurea">Annona purpurea</option>,
#  <option value="/imppat/phytochemical/Annona reticulata">Annona reticulata</option>,
#  <option value="/imppat/phytochemical/Annona squamosa">Annona squamosa</option>,
#  <option value="/imppat/phytochemical/Annona stenophylla">Annona stenophylla</option>,
#  <option value="/imppat/phytochemical/Anodendron paniculatum">Anodendron paniculatum</option>,
#  <option value="/imppat/phytochemical/Anoectochilus roxburghii">Anoectochilus roxburghii</option>,
#  <option value="/imppat/phytochemical/Anogeissus acuminata">Anogeissus acuminata</option>,
#  <option value="/imppat/phytochemical/Anogeissus latifolia">Anogeissus latifolia</option>,
#  <option value="/imppat/phytochemical/Anthemis cotula">Anthemis cotula</option>,
#  <option value="/imppat/phytochemical/Anthriscus cerefolium">Anthriscus cerefolium</option>,
#  <option value="/imppat/phytochemical/Anthriscus nemorosa">Anthriscus nemorosa</option>,
#  <option value="/imppat/phytochemical/Anthriscus sylvestris">Anthriscus sylvestris</option>,
#  <option value="/imppat/phytochemical/Antiaris toxicaria">Antiaris toxicaria</option>,
#  <option value="/imppat/phytochemical/Anticharis glandulosa">Anticharis glandulosa</option>,
#  <option value="/imppat/phytochemical/Anticharis senegalensis">Anticharis senegalensis</option>,
#  <option value="/imppat/phytochemical/Antidesma acidum">Antidesma acidum</option>,
#  <option value="/imppat/phytochemical/Antidesma bunius">Antidesma bunius</option>,
#  <option value="/imppat/phytochemical/Antidesma montanum">Antidesma montanum</option>,
#  <option value="/imppat/phytochemical/Antigonon leptopus">Antigonon leptopus</option>,
#  <option value="/imppat/phytochemical/Antirrhinum majus">Antirrhinum majus</option>,
#  <option value="/imppat/phytochemical/Apama siliquosa">Apama siliquosa</option>,
#  <option value="/imppat/phytochemical/Aphanamixis polystachya">Aphanamixis polystachya</option>,
#  <option value="/imppat/phytochemical/Aphananthe cuspidata">Aphananthe cuspidata</option>,
#  <option value="/imppat/phytochemical/Apium graveolens">Apium graveolens</option>,
#  <option value="/imppat/phytochemical/Apodytes dimidiata">Apodytes dimidiata</option>,
#  <option value="/imppat/phytochemical/Aquilaria agallocha">Aquilaria agallocha</option>,
#  <option value="/imppat/phytochemical/Arisaema tortuosum">Arisaema tortuosum</option>,
#  <option value="/imppat/phytochemical/Arisaema triphyllum">Arisaema triphyllum</option>,
#  <option value="/imppat/phytochemical/Aristolochia bracteolata">Aristolochia bracteolata</option>,
#  <option value="/imppat/phytochemical/Aristolochia fontanesii">Aristolochia fontanesii</option>,
#  <option value="/imppat/phytochemical/Aristolochia grandiflora">Aristolochia grandiflora</option>,
#  <option value="/imppat/phytochemical/Aristolochia indica">Aristolochia indica</option>,
#  <option value="/imppat/phytochemical/Aristolochia labiata">Aristolochia labiata</option>,
#  <option value="/imppat/phytochemical/Aristolochia littoralis">Aristolochia littoralis</option>,
#  <option value="/imppat/phytochemical/Aristolochia reticulata">Aristolochia reticulata</option>,
#  <option value="/imppat/phytochemical/Aristolochia ringens">Aristolochia ringens</option>,
#  <option value="/imppat/phytochemical/Aristolochia rotunda">Aristolochia rotunda</option>,
#  <option value="/imppat/phytochemical/Aristolochia serpentaria">Aristolochia serpentaria</option>,
#  <option value="/imppat/phytochemical/Aristolochia tagala">Aristolochia tagala</option>,
#  <option value="/imppat/phytochemical/Armoracia rusticana">Armoracia rusticana</option>,
#  <option value="/imppat/phytochemical/Arnebia euchroma">Arnebia euchroma</option>,
#  <option value="/imppat/phytochemical/Arnebia guttata">Arnebia guttata</option>,
#  <option value="/imppat/phytochemical/Arnebia hispidissima">Arnebia hispidissima</option>,
#  <option value="/imppat/phytochemical/Arnebia nobilis">Arnebia nobilis</option>,
#  <option value="/imppat/phytochemical/Arnica longifolia">Arnica longifolia</option>,
#  <option value="/imppat/phytochemical/Arnica montana">Arnica montana</option>,
#  <option value="/imppat/phytochemical/Arrhenatherum elatius">Arrhenatherum elatius</option>,
#  <option value="/imppat/phytochemical/Artabotrys hexapetalus">Artabotrys hexapetalus</option>,
#  <option value="/imppat/phytochemical/Artemisia abrotanum">Artemisia abrotanum</option>,
#  <option value="/imppat/phytochemical/Artemisia absinthium">Artemisia absinthium</option>,
#  <option value="/imppat/phytochemical/Artemisia annua">Artemisia annua</option>,
#  <option value="/imppat/phytochemical/Artemisia biennis">Artemisia biennis</option>,
#  <option value="/imppat/phytochemical/Artemisia capillaris">Artemisia capillaris</option>,
#  <option value="/imppat/phytochemical/Artemisia carvifolia">Artemisia carvifolia</option>,
#  <option value="/imppat/phytochemical/Artemisia cina">Artemisia cina</option>,
#  <option value="/imppat/phytochemical/Artemisia dracunculus">Artemisia dracunculus</option>,
#  <option value="/imppat/phytochemical/Artemisia gmelini">Artemisia gmelini</option>,
#  <option value="/imppat/phytochemical/Artemisia gmelinii">Artemisia gmelinii</option>,
#  <option value="/imppat/phytochemical/Artemisia halodendron">Artemisia halodendron</option>,
#  <option value="/imppat/phytochemical/Artemisia indica">Artemisia indica</option>,
#  <option value="/imppat/phytochemical/Artemisia japonica">Artemisia japonica</option>,
#  <option value="/imppat/phytochemical/Artemisia judaica">Artemisia judaica</option>,
#  <option value="/imppat/phytochemical/Artemisia laciniata">Artemisia laciniata</option>,
#  <option value="/imppat/phytochemical/Artemisia macrocephala">Artemisia macrocephala</option>,
#  <option value="/imppat/phytochemical/Artemisia maritima">Artemisia maritima</option>,
#  <option value="/imppat/phytochemical/Artemisia myriantha">Artemisia myriantha</option>,
#  <option value="/imppat/phytochemical/Artemisia nilagirica">Artemisia nilagirica</option>,
#  <option value="/imppat/phytochemical/Artemisia pallens">Artemisia pallens</option>,
#  <option value="/imppat/phytochemical/Artemisia persica">Artemisia persica</option>,
#  <option value="/imppat/phytochemical/Artemisia roxburghiana">Artemisia roxburghiana</option>,
#  <option value="/imppat/phytochemical/Artemisia salsoloides">Artemisia salsoloides</option>,
#  <option value="/imppat/phytochemical/Artemisia scoparia">Artemisia scoparia</option>,
#  <option value="/imppat/phytochemical/Artemisia sieversiana">Artemisia sieversiana</option>,
#  <option value="/imppat/phytochemical/Artemisia siversiana">Artemisia siversiana</option>,
#  <option value="/imppat/phytochemical/Artemisia vestita">Artemisia vestita</option>,
#  <option value="/imppat/phytochemical/Artemisia vulgaris">Artemisia vulgaris</option>,
#  <option value="/imppat/phytochemical/Arthrocnemum fruticosum">Arthrocnemum fruticosum</option>,
#  <option value="/imppat/phytochemical/Arthrocnemum indicum">Arthrocnemum indicum</option>,
#  <option value="/imppat/phytochemical/Arthrocnemum macrostachyum">Arthrocnemum macrostachyum</option>,
#  <option value="/imppat/phytochemical/Arthromeris wallichiana">Arthromeris wallichiana</option>,
#  <option value="/imppat/phytochemical/Artocarpus altilis">Artocarpus altilis</option>,
#  <option value="/imppat/phytochemical/Artocarpus chama">Artocarpus chama</option>,
#  <option value="/imppat/phytochemical/Artocarpus heterophyllus">Artocarpus heterophyllus</option>,
#  <option value="/imppat/phytochemical/Artocarpus hirsutus">Artocarpus hirsutus</option>,
#  <option value="/imppat/phytochemical/Artocarpus integer">Artocarpus integer</option>,
#  <option value="/imppat/phytochemical/Artocarpus lacucha">Artocarpus lacucha</option>,
#  <option value="/imppat/phytochemical/Artocarpus rigidus">Artocarpus rigidus</option>,
#  <option value="/imppat/phytochemical/Aruncus dioicus">Aruncus dioicus</option>,
#  <option value="/imppat/phytochemical/Arundina graminifolia">Arundina graminifolia</option>,
#  <option value="/imppat/phytochemical/Arundo donax">Arundo donax</option>,
#  <option value="/imppat/phytochemical/Asarum europaeum">Asarum europaeum</option>,
#  <option value="/imppat/phytochemical/Asarum himalaicum">Asarum himalaicum</option>,
#  <option value="/imppat/phytochemical/Asclepias curassavica">Asclepias curassavica</option>,
#  <option value="/imppat/phytochemical/Asparagus adscendens">Asparagus adscendens</option>,
#  <option value="/imppat/phytochemical/Asparagus aethiopicus">Asparagus aethiopicus</option>,
#  <option value="/imppat/phytochemical/Asparagus curillus">Asparagus curillus</option>,
#  <option value="/imppat/phytochemical/Asparagus filicinus">Asparagus filicinus</option>,
#  <option value="/imppat/phytochemical/Asparagus gonoclados">Asparagus gonoclados</option>,
#  <option value="/imppat/phytochemical/Asparagus officinalis">Asparagus officinalis</option>,
#  <option value="/imppat/phytochemical/Cochlospermum vitifolium">Cochlospermum vitifolium</option>,
#  <option value="/imppat/phytochemical/Cocos nucifera">Cocos nucifera</option>,
#  <option value="/imppat/phytochemical/Codariocalyx motorius">Codariocalyx motorius</option>,
#  <option value="/imppat/phytochemical/Codiaeum variegatum">Codiaeum variegatum</option>,
#  <option value="/imppat/phytochemical/Codonopsis clematidea">Codonopsis clematidea</option>,
#  <option value="/imppat/phytochemical/Codonopsis ovata">Codonopsis ovata</option>,
#  <option value="/imppat/phytochemical/Coelogyne corymbosa">Coelogyne corymbosa</option>,
#  <option value="/imppat/phytochemical/Coelogyne cristata">Coelogyne cristata</option>,
#  <option value="/imppat/phytochemical/Coelogyne nitida">Coelogyne nitida</option>,
#  <option value="/imppat/phytochemical/Coelogyne ovalis">Coelogyne ovalis</option>,
#  <option value="/imppat/phytochemical/Coelogyne stricta">Coelogyne stricta</option>,
#  <option value="/imppat/phytochemical/Coffea arabica">Coffea arabica</option>,
#  <option value="/imppat/phytochemical/Coffea benghalensis">Coffea benghalensis</option>,
#  <option value="/imppat/phytochemical/Coffea canephora">Coffea canephora</option>,
#  <option value="/imppat/phytochemical/Coix lacryma-jobi">Coix lacryma-jobi</option>,
#  <option value="/imppat/phytochemical/Cola acuminata">Cola acuminata</option>,
#  <option value="/imppat/phytochemical/Cola nitida">Cola nitida</option>,
#  <option value="/imppat/phytochemical/Colchicum autumnale">Colchicum autumnale</option>,
#  <option value="/imppat/phytochemical/Colchicum luteum">Colchicum luteum</option>,
#  <option value="/imppat/phytochemical/Colebrookea oppositifolia">Colebrookea oppositifolia</option>,
#  <option value="/imppat/phytochemical/Coleus forskohlii">Coleus forskohlii</option>,
#  <option value="/imppat/phytochemical/Colocasia esculenta">Colocasia esculenta</option>,
#  <option value="/imppat/phytochemical/Colophospermum mopane">Colophospermum mopane</option>,
#  <option value="/imppat/phytochemical/Colquhounia coccinea">Colquhounia coccinea</option>,
#  <option value="/imppat/phytochemical/Colubrina asiatica">Colubrina asiatica</option>,
#  <option value="/imppat/phytochemical/Combretum albidum">Combretum albidum</option>,
#  <option value="/imppat/phytochemical/Combretum indicum">Combretum indicum</option>,
#  <option value="/imppat/phytochemical/Combretum quadrangulare">Combretum quadrangulare</option>,
#  <option value="/imppat/phytochemical/Commelina benghalensis">Commelina benghalensis</option>,
#  <option value="/imppat/phytochemical/Commelina communis">Commelina communis</option>,
#  <option value="/imppat/phytochemical/Commelina erecta">Commelina erecta</option>,
#  ...]

# %%
soup.find_all("option")

# %%
clean_lst = []

for i in lst:
    clean_lst.append(i.text.strip())

# %%
df = pd.DataFrame(clean_lst, columns=['Phytochemicals'])
df.head()
# Out:
#            Phytochemicals
# 0    Choose from dropdown
# 1  Abelmoschus esculentus
# 2   Abelmoschus ficulneus
# 3     Abelmoschus manihot
# 4   Abelmoschus moschatus

# %%
df[df['Phytochemicals'] == 'Choose from dropdown'].index
# Out:
# Index([0, 4011, 21979, 22000, 26011], dtype='int64')

# %%
link_adder()
# Out:
# Phytochemicals    Choose from dropdown
# Name: 22000, dtype: object

# %%
v_df = pd.DataFrame(df.iloc[1:4011])
v_df.head()
# Out:
#            Phytochemicals
# 1  Abelmoschus esculentus
# 2   Abelmoschus ficulneus
# 3     Abelmoschus manihot
# 4   Abelmoschus moschatus
# 5              Abies alba

# %%
v_df.to_csv("IMPPAT_PhytoAssoc_Indian medicinal plants.csv", index=False)

# %%
w_df = pd.DataFrame(df.iloc[4012:21979])
w_df.head()
# Out:
#                                          Phytochemicals
# 4012  ((1R,2S,5R,6S)-5-(Benzoyloxy)-1,2,6-trihydroxy...
# 4013  ((1R,4S,5R)-1-Methyl-4-(prop-1-en-2-yl)spiro[4...
# 4014  ((1R,6S)-2-((2S,3R,4R,5S,6S)-3,4,5,6-tetrahydr...
# 4015  ((1S,5R,6S)-5-(Benzoyloxy)-1,6-dihydroxy-2-oxo...
# 4016  ((4aS,8S,8aR)-8-Isopropyl-5-methyl-3,4,4a,7,8,...

# %%
w_df.to_csv("IMPPAT_PhytoAssoc_Phytocemical.csv", index=False)

# %%
x_df = pd.DataFrame(df.iloc[21980:22000])
x_df.head()
# Out:
#                   Phytochemicals
# 21980                 Acetylides
# 21981  Alkaloids and derivatives
# 21982                    Allenes
# 21983                 Benzenoids
# 21984    Hydrocarbon derivatives

# %%
x_df.to_csv("IMPPAT_PhytoAssoc_Chemical_Superclass.csv", index=False)

# %%
y_df = pd.DataFrame(df.iloc[22001:26011])
y_df.head()
# Out:
#                Phytochemicals
# 22001  Abelmoschus esculentus
# 22002   Abelmoschus ficulneus
# 22003     Abelmoschus manihot
# 22004   Abelmoschus moschatus
# 22005              Abies alba

# %%
y_df.to_csv("IMPPAT_Therapeutic_Indian medicinal plants.csv", index=False)

# %%
z_df = pd.DataFrame(df.iloc[26012:27107])
z_df.head()
# Out:
#                                  Phytochemicals
# 26012  A bacterial disease on the soles of feet
# 26013              Abdominal digestive ailments
# 26014                             Abdominal fat
# 26015                        Abdominal injuries
# 26016                       Abdominal neoplasms

# %%
z_df.to_csv("IMPPAT_Therapeutic_diseases.csv", index=False)

# %%
chemo_name_lst = soup.find_all("a", href=True)
chemo_name_lst = chemo_name_lst[12:-9] # slice out unwanted items from the list
chemo_name_lst

# %%
len(chemo_name_lst)

# %%
chem_names_chemo_dict = {'Phytochemical': [], 'Link': []}

# %%
for chemo_name in chemo_name_lst:
    try:
        chem_names_chemo_dict['Phytochemical'].append(chemo_name.text.strip()) # add scientific name of the plant to dict 
        element = chemo_name.find("a", href=True)
        final_link = str("https://neist.res.in/osadhi/" + chemo_name['href'])
        chem_names_chemo_dict['Link'].append(final_link) # add link of the corresponding plant to dict 
    except TypeError:
        pass

# %%
chem_names_chemo_df = pd.DataFrame(chem_names_chemo_dict)
chem_names_chemo_df.head()

# %%
chem_names_chemo_df.to_csv("OSADHI_Chemo_ChemName_Links.csv", index=False)

# %% [markdown]
# # Scraping each plant's specific details

# %%
soup_man = """
<!DOCTYPE html>
"""

# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd
import time
from tqdm import tqdm
import json

# %%
HEADERS = ({'User-Agent': 'Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/130.0.0.0 Safari/537.36',
            'Accept-Language': 'en-US, en;q=0.5'})

# %%
url2 = "https://neist.res.in/osadhi/chemodetail.php?phyto=%0Adicerandrol+C"
webpage2 = requests.get(url2, headers=HEADERS)
soup2 = BeautifulSoup(webpage2.content, "html.parser")

# %%
main_dropdowns = soup2.find_all("div", class_='card-header')

for i in main_dropdowns:
    print(i.text.strip())

# %%
chemo_items_dict = {
'Physiochemical Properties' : {'Molecular Weight':'', 'nRot':'', 'Heavy Atom Molecular Weight':'', 'nRig':'', 'Exact Molecular Weight':'', 'nRing':'', 'Solubility: LogS':'', 'nHRing':'', 'Solubility: LogP':'', 'No. of Aliphatic Rings':'', 'Acid Count':'', 'No. of Aromatic Rings':'', 'Base Count':'', 'No. of Aliphatic Carbocycles Rings':'', 'Atoms Count':'', 'No. of Aliphatic Hetero Cycles':'', 'No. of Heavy Atom':'', 'No. of Aromatic Carbocycles':'', 'nHetero':'', 'No. of Aromatic Hetero Cycles':'', 'nBridge Head':'', 'No. Saturated Carbocycles':'', 'No. of Hydrogen atom':'', 'No. of Saturated Hetero Cycles':'', 'No. of Carbon atom':'', 'No. of Saturated Rings':'', 'No. of Nitrogen atom':'', 'No. of Arom Atom':'', 'No. of Oxygen atom':'', 'No. of Arom Bond':'', 'nHA':'', 'APOL':'', 'nHD':'', 'BPOL':''},
'Medicinal Chemistry Properties' : {'QED':'', 'Synth':'', 'Natural Product Likeliness':'', 'NR-PPAR-gamma':''},
'Drug Likeliness' : {'Lipinski':'', 'Pfizer':'', 'GSK':'', 'Golden Triangle':''},
'Absorption' : {'Pgp-inh':'', 'Pgp-sub':'', 'HIA':'', 'CACO-2':''},
'Distribution' : {'MDCK':'', 'BBB':'', 'PPB':'', 'VDSS':''},
'Metabolism' : {'FU':'', 'CYP1A2-inh':'', 'CYP1A2-sub':'', 'CYP2c19-inh':'', 'CYP2c19-sub':'', 'CYP2c9-inh':'', 'CYP2c9-sub':'', 'CYP2d6-inh':'', 'CYP2d6-sub':'', 'CYP3a4-inh':'', 'CYP3a4-sub':''},
'Excretion' : {'CL':'', 'T12':''},
'Toxicity' : {'hERG':'', 'Ames':'', 'ROA':'', 'SkinSen':'', 'Carcinogencity':'', 'EI':'', 'Respiratory':'', 'NR-Aromatase':''},
'Antiviral Prediction' : {'Antiviral':'', 'Prediction':''}
}

# %%
physicochemical_properties = ['Molecular Weight', 'nRot', 'Heavy Atom Molecular Weight', 'nRig', 'Exact Molecular Weight', 'nRing', 'Solubility: LogS', 'nHRing', 'Solubility: LogP', 'No. of Aliphatic Rings', 'Acid Count', 'No. of Aromatic Rings', 'Base Count', 'No. of Aliphatic Carbocycles Rings', 'Atoms Count', 'No. of Aliphatic Hetero Cycles', 'No. of Heavy Atom', 'No. of Aromatic Carbocycles', 'nHetero', 'No. of Aromatic Hetero Cycles', 'nBridge Head', 'No. Saturated Carbocycles', 'No. of Hydrogen atom', 'No. of Saturated Hetero Cycles', 'No. of Carbon atom', 'No. of Saturated Rings', 'No. of Nitrogen atom', 'No. of Arom Atom', 'No. of Oxygen atom', 'No. of Arom Bond', 'nHA', 'APOL', 'nHD', 'BPOL']
medicinal_chemistry_properties = ['QED', 'Synth', 'Natural Product Likeliness', 'NR-PPAR-gamma']
drug_likeliness = ['Lipinski', 'Pfizer', 'GSK', 'Golden Triangle']
absorption = ['Pgp-inh', 'Pgp-sub', 'HIA', 'CACO-2']
distribution = ['MDCK', 'BBB', 'PPB', 'VDSS']
metabolism = ['FU', 'CYP1A2-inh', 'CYP1A2-sub', 'CYP2c19-inh', 'CYP2c19-sub', 'CYP2c9-inh', 'CYP2c9-sub', 'CYP2d6-inh', 'CYP2d6-sub', 'CYP3a4-inh', 'CYP3a4-sub']
excretion = ['CL', 'T12']
toxicity = ['hERG', 'Ames', 'ROA', 'SkinSen', 'Carcinogencity', 'EI', 'Respiratory', 'NR-Aromatase']
antiviral_prediction = ['Antiviral', 'Prediction']

# %%
def add_details_to_dict(sub_header_lst):
    k=0
    for i in sub_header_lst:
        if k % 2 == 0: # heading
            heading = i.text.strip()
        else:          # values
            if heading in physicochemical_properties:
                chemo_items_dict['Physiochemical Properties'][heading] = str(i.text.strip())
            
            elif heading in medicinal_chemistry_properties:
                chemo_items_dict['Medicinal Chemistry Properties'][heading] = str(i.text.strip())
            
            elif heading in drug_likeliness:
                chemo_items_dict['Drug Likeliness'][heading] = str(i.text.strip())
            
            elif heading in absorption:
                chemo_items_dict['Absorption'][heading] = str(i.text.strip())
            
            elif heading in distribution:
                chemo_items_dict['Distribution'][heading] = str(i.text.strip())
            
            elif heading in metabolism:
                chemo_items_dict['Metabolism'][heading] = str(i.text.strip())
            
            elif heading in excretion:
                chemo_items_dict['Excretion'][heading] = str(i.text.strip())
            
            elif heading in toxicity:
                chemo_items_dict['Toxicity'][heading] = str(i.text.strip())
            
            elif heading in antiviral_prediction:
                chemo_items_dict['Antiviral Prediction'][heading] = str(i.text.strip())
        k+=1
    return chemo_items_dict


def check_sub_headers(sub_header_html):
    # sub_header_values_lst = []
    
    # j=0
    # for i in sub_header_html:
    #     if j%2 != 0:
    #         sub_header_values_lst.append(i.text.strip())
    #     j+=1
    # print(len(sub_header_values_lst)) 
    # print(sub_header_values_lst) 
    if len(sub_header_html) == 0:
        return "No" # no sub headers
    else:
        val_dict = add_details_to_dict(sub_header_html)
        return ("Yes", val_dict) # sub_header_values_lst # pass to subsequent function

# def get_website_html(plant_link):
#     webpage = requests.get(plant_link, headers=HEADERS)
#     soup = BeautifulSoup(webpage.content, "html.parser")
#     return soup

# %%
url2 = "https://neist.res.in/osadhi/chemodetail.php?phyto=%0Adicerandrol+C"
url3 = "https://neist.res.in/osadhi/chemodetail.php?phyto=+%281S%2C8%27R%29-6-methoxy-2-methylspiro%5B3%2C4-dihydroisoquinoline-1%2C7%27-6%2C8-dihydrocyclopenta%5Bg%5D%5B1%2C3%5Dbenzodioxole%5D-7%2C8%27-diol"
url4 = "https://neist.res.in/osadhi/chemodetail.php?phyto=%0AVitexin+2%27%27-O-beta-L-rhamnoside"
webpage3 = requests.get(url2, headers=HEADERS)
soup3 = BeautifulSoup(webpage3.content, "html.parser")

# soup_man2 = BeautifulSoup(soup_man, "html.parser")
# main_headers = soup_man2.find_all("div", class_='card-header')

main_headers = soup3.find_all("div", class_='card-header')

if not main_headers: # No main headers like  Physiochemical Properties, Metabolism etc
    print("main header - no")
elif main_headers: # Main headers present but no content in sub-headers
    print("main header - yes")
    sub_headers = soup_man2.find_all("td")
    reply, sub_headers_with_values = check_sub_headers(sub_headers)
    print(reply,"\n", sub_headers_with_values)
# Out:
# ---------------------------------------------------------------------------
# gaierror                                  Traceback (most recent call last)
# File ~/anaconda3/lib/python3.9/site-packages/urllib3/connection.py:174, in HTTPConnection._new_conn(self)
#     173 try:
# --> 174     conn = connection.create_connection(
#     175         (self._dns_host, self.port), self.timeout, **extra_kw
#     176     )
#     178 except SocketTimeout:
#
# File ~/anaconda3/lib/python3.9/site-packages/urllib3/util/connection.py:72, in create_connection(address, timeout, source_address, socket_options)
#      68     return six.raise_from(
#      69         LocationParseError(u"'%s', label empty or too long" % host), None
#      70     )
# ---> 72 for res in socket.getaddrinfo(host, port, family, socket.SOCK_STREAM):
#      73     af, socktype, proto, canonname, sa = res
#
# File ~/anaconda3/lib/python3.9/socket.py:966, in getaddrinfo(host, port, family, type, proto, flags)
#     965 addrlist = []
# --> 966 for res in _socket.getaddrinfo(host, port, family, type, proto, flags):
#     967     af, socktype, proto, canonname, sa = res
#
# gaierror: [Errno -3] Temporary failure in name resolution
#
# During handling of the above exception, another exception occurred:
#
# NewConnectionError                        Traceback (most recent call last)
# File ~/anaconda3/lib/python3.9/site-packages/urllib3/connectionpool.py:715, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     714 # Make the request on the httplib connection object.
# --> 715 httplib_response = self._make_request(
#     716     conn,
#     717     method,
#     718     url,
#     719     timeout=timeout_obj,
#     720     body=body,
#     721     headers=headers,
#     722     chunked=chunked,
#     723 )
#     725 # If we're going to release the connection in ``finally:``, then
#     726 # the response doesn't need to know about the connection. Otherwise
#     727 # it will also try to release it and we'll have a double-release
#     728 # mess.
#
# File ~/anaconda3/lib/python3.9/site-packages/urllib3/connectionpool.py:404, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     403 try:
# --> 404     self._validate_conn(conn)
#     405 except (SocketTimeout, BaseSSLError) as e:
#     406     # Py2 raises this as a BaseSSLError, Py3 raises it as socket timeout.
#
# File ~/anaconda3/lib/python3.9/site-packages/urllib3/connectionpool.py:1060, in HTTPSConnectionPool._validate_conn(self, conn)
#    1059 if not getattr(conn, "sock", None):  # AppEngine might not have  `.sock`
# -> 1060     conn.connect()
#    1062 if not conn.is_verified:
#
# File ~/anaconda3/lib/python3.9/site-packages/urllib3/connection.py:363, in HTTPSConnection.connect(self)
#     361 def connect(self):
#     362     # Add certificate verification
# --> 363     self.sock = conn = self._new_conn()
#     364     hostname = self.host
#
# File ~/anaconda3/lib/python3.9/site-packages/urllib3/connection.py:186, in HTTPConnection._new_conn(self)
#     185 except SocketError as e:
# --> 186     raise NewConnectionError(
#     187         self, "Failed to establish a new connection: %s" % e
#     188     )
#     190 return conn
#
# NewConnectionError: <urllib3.connection.HTTPSConnection object at 0x7effb9960f40>: Failed to establish a new connection: [Errno -3] Temporary failure in name resolution
#
# During handling of the above exception, another exception occurred:
#
# MaxRetryError                             Traceback (most recent call last)
# File ~/anaconda3/lib/python3.9/site-packages/requests/adapters.py:667, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     666 try:
# --> 667     resp = conn.urlopen(
#     668         method=request.method,
#     669         url=url,
#     670         body=request.body,
#     671         headers=request.headers,
#     672         redirect=False,
#     673         assert_same_host=False,
#     674         preload_content=False,
#     675         decode_content=False,
#     676         retries=self.max_retries,
#     677         timeout=timeout,
#     678         chunked=chunked,
#     679     )
#     681 except (ProtocolError, OSError) as err:
#
# File ~/anaconda3/lib/python3.9/site-packages/urllib3/connectionpool.py:801, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     799     e = ProtocolError("Connection aborted.", e)
# --> 801 retries = retries.increment(
#     802     method, url, error=e, _pool=self, _stacktrace=sys.exc_info()[2]
#     803 )
#     804 retries.sleep()
#
# File ~/anaconda3/lib/python3.9/site-packages/urllib3/util/retry.py:594, in Retry.increment(self, method, url, response, error, _pool, _stacktrace)
#     593 if new_retry.is_exhausted():
# --> 594     raise MaxRetryError(_pool, url, error or ResponseError(cause))
#     596 log.debug("Incremented Retry for (url='%s'): %r", url, new_retry)
#
# MaxRetryError: HTTPSConnectionPool(host='neist.res.in', port=443): Max retries exceeded with url: /osadhi/chemodetail.php?phyto=%0Adicerandrol+C (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x7effb9960f40>: Failed to establish a new connection: [Errno -3] Temporary failure in name resolution'))
#
# During handling of the above exception, another exception occurred:
#
# ConnectionError                           Traceback (most recent call last)
# Cell In[65], line 4
#       2 url3 = "https://neist.res.in/osadhi/chemodetail.php?phyto=+%281S%2C8%27R%29-6-methoxy-2-methylspiro%5B3%2C4-dihydroisoquinoline-1%2C7%27-6%2C8-dihydrocyclopenta%5Bg%5D%5B1%2C3%5Dbenzodioxole%5D-7%2C8%27-diol"
#       3 url4 = "https://neist.res.in/osadhi/chemodetail.php?phyto=%0AVitexin+2%27%27-O-beta-L-rhamnoside"
# ----> 4 webpage3 = requests.get(url2, headers=HEADERS)
#       5 soup3 = BeautifulSoup(webpage3.content, "html.parser")
#       7 # soup_man2 = BeautifulSoup(soup_man, "html.parser")
#       8 # main_headers = soup_man2.find_all("div", class_='card-header')
#
# File ~/anaconda3/lib/python3.9/site-packages/requests/api.py:73, in get(url, params, **kwargs)
#      62 def get(url, params=None, **kwargs):
#      63     r"""Sends a GET request.
#      64
#      65     :param url: URL for the new :class:`Request` object.
#    (...)
#      70     :rtype: requests.Response
#      71     """
# ---> 73     return request("get", url, params=params, **kwargs)
#
# File ~/anaconda3/lib/python3.9/site-packages/requests/api.py:59, in request(method, url, **kwargs)
#      55 # By using the 'with' statement we are sure the session is closed, thus we
#      56 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      57 # cases, and look like a memory leak in others.
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File ~/anaconda3/lib/python3.9/site-packages/requests/sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File ~/anaconda3/lib/python3.9/site-packages/requests/sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File ~/anaconda3/lib/python3.9/site-packages/requests/adapters.py:700, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     696     if isinstance(e.reason, _SSLError):
#     697         # This branch is for urllib3 v1.22 and later.
#     698         raise SSLError(e, request=request)
# --> 700     raise ConnectionError(e, request=request)
#     702 except ClosedPoolError as e:
#     703     raise ConnectionError(e, request=request)
#
# ConnectionError: HTTPSConnectionPool(host='neist.res.in', port=443): Max retries exceeded with url: /osadhi/chemodetail.php?phyto=%0Adicerandrol+C (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x7effb9960f40>: Failed to establish a new connection: [Errno -3] Temporary failure in name resolution'))

# %%
len(soup_man2.find_all("td"))
# Out:
# 146

# %%
soup2.find("div", class_='card-body')

# %%
soup2.find_all('td')

# %%
chemo_values = []

# %%
inside_info = soup2.find_all('td')

j=0
for i in inside_info:
    if j%2 != 0:
        chemo_values.append(i.text.strip())
    j+=1

# %%
for i in lst:
    if i % 2 == 0: # heading
        heading = i.text.strip()
    else:          # values
        if heading in physicochemical_properties:
            chemo_items_dict['Physiochemical Properties'][heading] = str(i.text.strip())
        
        elif heading in medicinal_chemistry_properties:
            chemo_items_dict['Medicinal Chemistry Properties'][heading] = str(i.text.strip())
        
        elif heading in drug_likeliness:
            chemo_items_dict['Drug Likeliness'][heading] = str(i.text.strip())
        
        elif heading in absorption:
            chemo_items_dict['Absorption'][heading] = str(i.text.strip())
        
        elif heading in distribution:
            chemo_items_dict['Distribution'][heading] = str(i.text.strip())
        
        elif heading in metabolism:
            chemo_items_dict['Metabolism'][heading] = str(i.text.strip())
        
        elif heading in excretion:
            chemo_items_dict['Excretion'][heading] = str(i.text.strip())
        
        elif heading in toxicity:
            chemo_items_dict['Toxicity'][heading] = str(i.text.strip())
        
        elif heading in antiviral_prediction:
            chemo_items_dict['Antiviral Prediction'][heading] = str(i.text.strip())

# %%
all_plant_info_dict = {}

def get_plant_website_html(plant_link):
    plant_webpage = requests.get(plant_link, headers=HEADERS)
    plant_soup = BeautifulSoup(plant_webpage.content, "html.parser")
    return plant_soup

def add_per_plant_details(soup, per_plant_details_dict):
    per_plant_details_dict = {
        'Summary': [],
        'Statewise availability': [],
        'Phytochemicals': [],
        'Ailments cured': [],
        'Plant parts and method of its use': [],
        'Vernacular name': []
        }
    
    for i in range(0, 6):
        if i == 0:
            for j in soup.table.find_all('ul')[i]:
                per_plant_details_dict['Summary'].append(j.text)
        if i == 1:
            for j in soup.table.find_all('ul')[i]:
                per_plant_details_dict['Statewise availability'].append(j.text)
        if i == 2:
            for j in soup.table.find_all('ul')[i]:
                per_plant_details_dict['Phytochemicals'].append(j.text)
        if i == 3:
            for j in soup.table.find_all('ul')[i]:
                per_plant_details_dict['Ailments cured'].append(j.text)
        if i == 4:
            for j in soup.table.find_all('ul')[i]:
                per_plant_details_dict['Plant parts and method of its use'].append(j.text)
        if i == 5:
            for j in soup.table.find_all('ul')[i]:
                per_plant_details_dict['Vernacular name'].append(j.text)

    return per_plant_details_dict

# %%
df = pd.read_csv("OSADHI_Ethno_Scientific_Name_Links.csv")
df.head(3)

# %%
loop_range = range(1494, len(df['Scientific Name']))
big_pause = 0

for i in tqdm((loop_range), desc="Processing"):
    plant_name = df['Scientific Name'][i]
    plant_link = df['Link'][i]

    plant_website_html = get_plant_website_html(plant_link) # getting HTML of plant details website
    per_plant_details = add_per_plant_details(plant_website_html, all_plant_info_dict) # collecting plant info to a dict
    all_plant_info_dict[plant_name] = per_plant_details # adding collected plant info to a main dict with plant sci name as key
    
    big_pause += 1
    if big_pause % 50 == 0:
        time.sleep(2) # after continuous 50 runs, long break for server

# %%
with open("OSADHI_all_plant_details_json_file_NEW.json", "w") as FinalOut: 
    json.dump(all_plant_info_dict, FinalOut)

# %%
abc = None

if abc:
    print('yes')
else:
    print('no')
# Out:
# no

# %% [markdown]
# # Merging JSONs

# %%
with open('OSADHI_all_plant_details_json_file_1.json') as f:
    data1 = json.load(f)
    
with open('OSADHI_all_plant_details_json_file_NEW.json') as f: 
    data2 = json.load(f)

data1.update(data2)

with open('OSADHI_all_plant_details_json_file.json', 'w') as f:
   json.dump(data1, f)

# %%
with open('OSADHI_all_plant_details_json_file.json') as f:
    item_dict = json.load(f)

len(item_dict)

# %%
sci_name_lst = df['Scientific Name'].tolist()

# %%
for key, _ in item_dict.items():
    try:
        sci_name_lst.remove(key)
    except ValueError:
        pass

# %%
sci_name_lst

# %%
item_dict

# %% [markdown]
# # Converting JSON to CSV

# %%
import json
import pandas as pd

# %%
with open('OSADHI_all_plants.json') as f:
    item_dict = json.load(f)

# %%
# item_dict's SUMMARY column DataFrame (df) 

first_entry = list(item_dict.values())[0]
headers = [item.split(':')[0] for item in first_entry['Summary']]  # use first entry to get headers
# headers expected output ['Scientific Name', 'Genus', 'Species', 'Family', 'Synonym']

rows = []

for plant_name, plant_data in item_dict.items():
    summary = plant_data.get('Summary', []) # extracting Summary values
    row = {}
    for idx, header in enumerate(headers):
        # Match summary items with corresponding headers
        row[header] = summary[idx].split(':')[1] if idx < len(summary) else ''

    rows.append(row)

df = pd.DataFrame(rows, columns=headers)
df.head()

# %%
# item_dict's remaining column DataFrame (df1)

df1 = pd.DataFrame.from_dict(item_dict, orient='index')
df1 = df1.map(lambda x: ', '.join(x) if isinstance(x, list) else x)
df1.drop('Summary', axis=1, inplace=True)
df1.head()

# %%
# merging both dfs, df and df1

merged_df = pd.concat([df.reset_index(drop=True), df1.reset_index(drop=True)], axis=1)
merged_df.head()

# %%
merged_df.to_csv("OSADHI_ethno_all_plant_details.csv", index=False)

# %% [markdown]
# # Converting JSON to CSV (for nested dictionary)

# %%
with open('chemo.json') as f: 
    data = json.load(f)

# %%
# new_dict = {}
all_dict = {}

for k, v in data.items():
    # print(k, v)
    new_dict = {}
    for ke, va in v.items():
        # print(ke, va)
        for key, val in va.items():
            # print(f"{ke}_{key} : {val}")
            new_dict[f"{ke} {key}"] = val
    all_dict[k] = new_dict

df = pd.DataFrame(all_dict).T
df.head()
# Out:
#                  Physiochemical Properties Molecular Weight  \
# auricularic acid                                    302.458
# d-glucose                                           180.156
# EUDESMANE                                           208.389
# orientin                                             448.38
# oxalic acid                                          90.034
#
#                  Physiochemical Properties nRot  \
# auricularic acid                              2
# d-glucose                                     1
# EUDESMANE                                     1
# orientin                                      3
# oxalic acid                                   0
#
#                  Physiochemical Properties Heavy Atom Molecular Weight  \
# auricularic acid                                            272.218
# d-glucose                                                    168.06
# EUDESMANE                                                   180.165
# orientin                                                     428.22
# oxalic acid                                                  88.018
#
#                  Physiochemical Properties nRig  \
# auricularic acid                             19
# d-glucose                                     6
# EUDESMANE                                    11
# orientin                                     24
# oxalic acid                                   2
#
#                  Physiochemical Properties Exact Molecular Weight  \
# auricularic acid                                          302.225
# d-glucose                                                 180.063
# EUDESMANE                                                 208.219
# orientin                                                  448.101
# oxalic acid                                               89.9953
#
#                  Physiochemical Properties nRing  \
# auricularic acid                               3
# d-glucose                                      1
# EUDESMANE                                      2
# orientin                                       4
# oxalic acid                                    0
#
#                  Physiochemical Properties Solubility: LogS  \
# auricularic acid                                     -4.698
# d-glucose                                            -0.017
# EUDESMANE                                            -6.093
# orientin                                             -3.741
# oxalic acid                                            0.24
#
#                  Physiochemical Properties nHRing  \
# auricularic acid                                0
# d-glucose                                       1
# EUDESMANE                                       0
# orientin                                        2
# oxalic acid                                     0
#
#                  Physiochemical Properties Solubility: LogP  \
# auricularic acid                                      4.505
# d-glucose                                            -2.499
# EUDESMANE                                             5.564
# orientin                                             -0.067
# oxalic acid                                          -0.735
#
#                  Physiochemical Properties No. of Aliphatic Rings  ...  \
# auricularic acid                                                3  ...
# d-glucose                                                       1  ...
# EUDESMANE                                                       2  ...
# orientin                                                        1  ...
# oxalic acid                                                     0  ...
#
#                  Toxicity hERG Toxicity Ames Toxicity ROA Toxicity SkinSen  \
# auricularic acid         0.007         0.015          0.3            0.065
# d-glucose                0.039         0.203        0.139             0.04
# EUDESMANE                0.033         0.019        0.029            0.483
# orientin                 0.024         0.822        0.099            0.342
# oxalic acid              0.024         0.026        0.038            0.504
#
#                  Toxicity Carcinogencity Toxicity EI Toxicity Respiratory  \
# auricularic acid                   0.107       0.026                0.904
# d-glucose                          0.013       0.025                 0.03
# EUDESMANE                          0.039       0.948                0.293
# orientin                           0.035       0.061                0.036
# oxalic acid                        0.014       0.994                0.068
#
#                  Toxicity NR-Aromatase Antiviral Prediction Antiviral  \
# auricularic acid                 0.012                             No
# d-glucose                        0.004                             No
# EUDESMANE                        0.006                            Yes
# orientin                         0.943                            Yes
# oxalic acid                      0.005                             No
#
#                  Antiviral Prediction Prediction
# auricularic acid                         0.54248
# d-glucose                               0.893736
# EUDESMANE                               0.834177
# orientin                                0.879454
# oxalic acid                                0.933
#
# [5 rows x 73 columns]

# %%
df.shape
# Out:
# (20776, 73)

# %%
df = df.rename_axis('Phytochemical').reset_index()
df.head()
# Out:
#       Phytochemical Physiochemical Properties Molecular Weight  \
# 0  auricularic acid                                    302.458
# 1         d-glucose                                    180.156
# 2         EUDESMANE                                    208.389
# 3          orientin                                     448.38
# 4       oxalic acid                                     90.034
#
#   Physiochemical Properties nRot  \
# 0                              2
# 1                              1
# 2                              1
# 3                              3
# 4                              0
#
#   Physiochemical Properties Heavy Atom Molecular Weight  \
# 0                                            272.218
# 1                                             168.06
# 2                                            180.165
# 3                                             428.22
# 4                                             88.018
#
#   Physiochemical Properties nRig  \
# 0                             19
# 1                              6
# 2                             11
# 3                             24
# 4                              2
#
#   Physiochemical Properties Exact Molecular Weight  \
# 0                                          302.225
# 1                                          180.063
# 2                                          208.219
# 3                                          448.101
# 4                                          89.9953
#
#   Physiochemical Properties nRing Physiochemical Properties Solubility: LogS  \
# 0                               3                                     -4.698
# 1                               1                                     -0.017
# 2                               2                                     -6.093
# 3                               4                                     -3.741
# 4                               0                                       0.24
#
#   Physiochemical Properties nHRing Physiochemical Properties Solubility: LogP  \
# 0                                0                                      4.505
# 1                                1                                     -2.499
# 2                                0                                      5.564
# 3                                2                                     -0.067
# 4                                0                                     -0.735
#
#    ... Toxicity hERG Toxicity Ames Toxicity ROA Toxicity SkinSen  \
# 0  ...         0.007         0.015          0.3            0.065
# 1  ...         0.039         0.203        0.139             0.04
# 2  ...         0.033         0.019        0.029            0.483
# 3  ...         0.024         0.822        0.099            0.342
# 4  ...         0.024         0.026        0.038            0.504
#
#   Toxicity Carcinogencity Toxicity EI Toxicity Respiratory  \
# 0                   0.107       0.026                0.904
# 1                   0.013       0.025                 0.03
# 2                   0.039       0.948                0.293
# 3                   0.035       0.061                0.036
# 4                   0.014       0.994                0.068
#
#   Toxicity NR-Aromatase Antiviral Prediction Antiviral  \
# 0                 0.012                             No
# 1                 0.004                             No
# 2                 0.006                            Yes
# 3                 0.943                            Yes
# 4                 0.005                             No
#
#   Antiviral Prediction Prediction
# 0                         0.54248
# 1                        0.893736
# 2                        0.834177
# 3                        0.879454
# 4                           0.933
#
# [5 rows x 74 columns]

# %%
df.to_csv("OSADHI_Chemo_all.csv", index='False')
